# %%
from flask import Flask
from flask_pymongo import PyMongo, MongoClient
import csv
import pymongo
from array import array
import numpy as np

# %%
app = Flask(__name__)
#use flask pymongo to set up the connection to the database
app.config['MONGO_CONNECT'] = False
client = MongoClient("mongodb+srv://FinalProject5Admin:crXD!E&zMpj9Fbs#@cluster0.1f8gahm.mongodb.net/?retryWrites=true&w=majority")
db = client.images

# %%
pixelsDataBase = client['images']

# %%
collectionDataHorses = pixelsDataBase['horse_image_list']
collectionDataSheep = pixelsDataBase['sheep_image_list']

# %%
cursorHorse = collectionDataHorses.find()
cursorSheep = collectionDataSheep.find()
horsePixels = []
sheepPixels = []

# %%
for record in cursorHorse:
    horsePixels.append(record)

# %%
for record in cursorSheep:
    sheepPixels.append(record)

# %%
print(f"Horse object count:{len(horsePixels)}, Sheep object count: {len(sheepPixels)}")

# %%
#prints all the pixels, make laggy
for item in horsePixels:
    print(item)

# %%
print(horsePixels[0]['_id'])

# %%
print(horsePixels[0]['data'])

# %%
##DIDN't WORK TRIED Convert a List of Strings to Ints Using for Loop in Python

#https://www.pythonforbeginners.com/basics/convert-a-list-of-strings-to-ints-in-python

pixelStrList = horsePixels[0]['data']
pixelIntList = []
for string in pixelStrList:
    is_digit = string.isdigit()
    if is_digit:
        myInt = int(string)
        pixelIntList.append(myInt)
    else:
        print("'{}'cannot be converted into an integer.".format(string))
print(pixelIntList)

# %%
#Convert a List of Lists of Strings to Ints Using for Loop in Python

pixelStrList = horsePixels[0]['data']
pixelIntList = []


for inner_list in pixelStrList:
    temp_list = []
    for element in inner_list:
        temp_list2=[]
        print(type(element))
        for element1 in element:
            #is_digit = element1.isdigit()
            print(type(element1))
            #if is_digit:
                #myInt = int(element)
                #temp_list2.append(myInt)
            #else:
                #print("'{}' cannot be converted into an integer.".format(element1))
        #temp_list.append(temp_list2)
    #pixelIntList.append(temp_list)

#print("The list of lists of ints is:")
#print(pixelIntList)

# %%
##NEXT TRY 3 FOR LOOP LEVELS TOO MANY 

pixelStrList = horsePixels[0]['data']
pixelIntList = []

for outter_list in pixelStrList:
    temp_list = []
    for inner_list in outter_list:
        temp_list1 = []
        for element in inner_list:
            is_digit = element.isdigit()
            if is_digit:
                myInt = int(element)
                temp_list1.appen(myInt)
            else:
                print("'{}' cannot be converted into an integer.".format(element))
        pixelIntList.append(temp_list1)
        
print(pixelIntList)

# %%
#4 lvls TOO MANY LEVELS

pixelStrList = horsePixels[0]['data']
pixelIntList = []

for mostOut in pixelStrList:
    temp_list = []
    for outter_list in mostOut:
        for inner_list in outter_list:
            for element in inner_list:
                is_digit = element.isdigit()
                if is_digit:
                    myInt = int(element)
                    temp_list.appen(myInt)
                else:
                    print("'{}' cannot be converted into an integer.".format(element))
    pixelIntList.append(temp_list)  

print(pixelIntList)

# %%
#print(horsePixels[0]['data'])
xHold = horsePixels[0]['data']
arrayTest = array("object", xHold)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 3>()
#       1 #print(horsePixels[0]['data'])
#       2 xHold = horsePixels[0]['data']
# ----> 3 arrayTest = array("object", xHold)
#
# TypeError: array() argument 1 must be a unicode character, not str

# %%
from keras.datasets import cifar10

# %%
test = cifar10.load_data()

# %%
##this is the goal of how i want the data
print(test)
# Out:
# ((array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
# ...

# %%
##Convert the Dictionary of lists, to a list of lists

res = [[key for key in horsePixels[0].keys()], *[list(idx.values()) for idx in test_list ]]

# %%
allHorsePixels = []

for object in horsePixels:
    allHorsePixels.append(horsePixels[object]['data'])

# %%
for i in range(len(horsePixels)):

# %%
print(len(horsePixels))

# %%
for i in range(len(horsePixels)):
    print("Picture #" + str(i))
    for key,values in horsePixels[i].items():
        #print(key,values)
        if key == "data":
            for j in range(len(values)):
                print("Row #" + str(j))
                for k in range(len(values[j])):
                    print(values[j][k])
    input("Press Enter to continue ...")
# Out:
# Picture #0
# Row #0
# [3, 0, 4]
# [3, 0, 2]
# [0, 0, 0]
# [10, 12, 7]
# [89, 97, 86]
# [104, 116, 102]
# [112, 126, 109]
# [115, 132, 114]
# [167, 186, 167]
# [173, 191, 175]
# [202, 219, 203]
# [186, 200, 183]
# [147, 160, 143]
# [190, 201, 184]
# [250, 255, 240]
# [240, 247, 229]
# [244, 244, 254]
# [248, 250, 255]
# [240, 241, 255]
# [228, 231, 250]
# [204, 210, 226]
# [135, 144, 149]
# [142, 153, 147]
# [102, 115, 98]
# [102, 115, 95]
# [87, 100, 82]
# [105, 115, 104]
# [68, 75, 68]
# [0, 5, 1]
# [0, 2, 0]
# [4, 6, 0]
# [0, 3, 0]
# Row #1
# [5, 0, 6]
# [3, 0, 2]
# [0, 0, 0]
# [5, 7, 2]
# [84, 92, 81]
# [98, 110, 96]
# [107, 121, 104]
# [109, 126, 108]
# [122, 141, 122]
# [125, 143, 127]
# [153, 170, 154]
# [145, 159, 144]
# [114, 127, 110]
# [155, 166, 149]
# [217, 226, 207]
# [216, 223, 205]
# [237, 238, 243]
# [242, 242, 252]
# [238, 240, 255]
# [236, 239, 255]
# [221, 227, 241]
# [156, 163, 169]
# [153, 164, 156]
# [107, 120, 103]
# [96, 109, 89]
# [86, 97, 80]
# ...

# %%
(x_train, y_train), (x_test,y_test) = horsePixels[]
