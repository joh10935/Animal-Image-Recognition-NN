# %%
import tensorflow as tf
import os
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
animal_model = tf.keras.models.load_model('models/full_animal_modelv3.h5')

# Check its architecture
animal_model.summary()
# Out:
# 2022-11-29 16:55:14.591762: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 128)     3584
#
#  batch_normalization (BatchN  (None, 254, 254, 128)    512
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 128)    0
#  )
#
#  dropout (Dropout)           (None, 127, 127, 128)     0
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      73792
#
#  batch_normalization_1 (Batc  (None, 125, 125, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
# ...

# %%
img = cv2.imread('../Test Images/butterfly.jpg')
resized = tf.image.resize(img, (256,256))
np.expand_dims(resized, 0).shape

# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = animal_model.predict(np.expand_dims(resizeB/255,0))
prediction
# Out:
# 1/1 [==============================] - 0s 266ms/step
# array([[0.40043023, 0.00367068, 0.00402877, 0.24222708, 0.11413743,
#         0.0066056 , 0.09556692, 0.09181933, 0.0234669 , 0.01804711]],
#       dtype=float32)

# %%
# Category with highest probability
print(f'highest probability is for label {np.argmax(prediction, axis =1)[0]}')
# Out:
# highest probability is for label 0

# %%
img = cv2.imread('../Test Images/chicken.png')
resized = tf.image.resize(img, (256,256))
np.expand_dims(resized, 0).shape

# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = animal_model.predict(np.expand_dims(resizeB/255,0))
prediction
# Out:
# 1/1 [==============================] - 0s 74ms/step
# array([[0.05990804, 0.05722348, 0.6210869 , 0.00870453, 0.09429838,
#         0.08111323, 0.01802234, 0.00158263, 0.05072004, 0.00734043]],
#       dtype=float32)

# %%
# Category with highest probability
print(f'highest probability is for label {np.argmax(prediction, axis =1)[0]}')
# Out:
# highest probability is for label 2

# %%
img = cv2.imread('../Test Images/horse.jpg')
resized = tf.image.resize(img, (256,256))
np.expand_dims(resized, 0).shape

# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = animal_model.predict(np.expand_dims(resized/255,0))
prediction
# Out:
# 1/1 [==============================] - 0s 66ms/step
# array([[0.6533179 , 0.00296367, 0.02450347, 0.06091013, 0.04941798,
#         0.03007939, 0.16777   , 0.00507241, 0.00445357, 0.00151149]],
#       dtype=float32)

# %%
# Category with highest probability
print(f'highest probability is for label {np.argmax(prediction, axis =1)}')
# Out:
# highest probability is for label [0]

# %%
img = cv2.imread('../Test Images/kitty_test.jpg')
resized = tf.image.resize(img, (256,256))
np.expand_dims(resized, 0).shape

# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = animal_model.predict(np.expand_dims(resized/255,0))
prediction
# Out:
# 1/1 [==============================] - 0s 70ms/step
# array([[3.66507447e-03, 4.95832086e-01, 1.16732106e-01, 7.09518185e-03,
#         9.85038206e-02, 9.81294736e-03, 2.01127375e-03, 7.20472187e-02,
#         3.08558410e-05, 1.94269508e-01]], dtype=float32)

# %%
# Category with highest probability
print(f'highest probability is for label {np.argmax(prediction, axis =1)}')
# Out:
# highest probability is for label [1]

# %%
img = cv2.imread('../Test Images/spider.jpg')
resized = tf.image.resize(img, (256,256))
np.expand_dims(resized, 0).shape

# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = animal_model.predict(np.expand_dims(resized/255,0))
prediction
# Out:
# 1/1 [==============================] - 0s 66ms/step
# array([[1.8087968e-04, 2.4298808e-04, 8.5209313e-06, 6.8562805e-08,
#         2.3949517e-05, 2.0788717e-07, 7.7584627e-06, 1.1124390e-06,
#         9.9952531e-01, 9.1874745e-06]], dtype=float32)

# %%
# Category with highest probability
print(f'highest probability is for label {np.argmax(prediction, axis =1)}')
# Out:
# highest probability is for label [8]

# %%
img = cv2.imread('../Test Images/dog.jpg')
resized = tf.image.resize(img, (256,256))
np.expand_dims(resized, 0).shape

# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = animal_model.predict(np.expand_dims(resized/255,0))
prediction
# Out:
# 1/1 [==============================] - 0s 83ms/step
# array([[0.3682396 , 0.00584084, 0.05934364, 0.05563989, 0.09967813,
#         0.00874033, 0.37997213, 0.00407655, 0.01575754, 0.00271133]],
#       dtype=float32)

# %%
# Category with highest probability
print(f'highest probability is for label {np.argmax(prediction, axis =1)}')
# Out:
# highest probability is for label [6]

# %%
img = cv2.imread('../Test Images/squirrel.jpg')
resized = tf.image.resize(img, (256,256))
np.expand_dims(resized, 0).shape

# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = animal_model.predict(np.expand_dims(resized/255,0))
prediction
# Out:
# 1/1 [==============================] - 0s 69ms/step
# array([[0.0031892 , 0.11363322, 0.06262553, 0.04971506, 0.22043468,
#         0.3448648 , 0.1022626 , 0.02921839, 0.026715  , 0.04734155]],
#       dtype=float32)

# %%
# Category with highest probability
print(f'highest probability is for label {np.argmax(prediction, axis =1)}')
# Out:
# highest probability is for label [5]

# %%
img = cv2.imread('../Test Images/sheep.png')
resized = tf.image.resize(img, (256,256))
np.expand_dims(resized, 0).shape

# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = animal_model.predict(np.expand_dims(resized/255,0))
prediction
# Out:
# 1/1 [==============================] - 0s 157ms/step
# array([[3.2590568e-04, 3.6935362e-03, 5.5839219e-03, 2.2400094e-02,
#         3.4445866e-03, 2.8997974e-02, 4.3815354e-04, 9.2980433e-01,
#         1.3553884e-04, 5.1758434e-03]], dtype=float32)

# %%
# Category with highest probability
print(f'highest probability is for label {np.argmax(prediction, axis =1)}')
# Out:
# highest probability is for label [7]

# %%
img = cv2.imread('../Test Images/cow.png')
resized = tf.image.resize(img, (256,256))
np.expand_dims(resized, 0).shape

# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = animal_model.predict(np.expand_dims(resized/255,0))
prediction
# Out:
# 1/1 [==============================] - 0s 88ms/step
# array([[1.1609612e-04, 9.8209642e-02, 3.0691942e-02, 5.4288810e-01,
#         5.1119365e-02, 4.5635700e-02, 3.2958645e-02, 1.9221735e-01,
#         7.2514165e-05, 6.0905912e-03]], dtype=float32)

# %%
# Category with highest probability
print(f'highest probability is for label {np.argmax(prediction, axis =1)}')
# Out:
# highest probability is for label [3]

# %%
img = cv2.imread('../Test Images/squirrel.png')
resized = tf.image.resize(img, (256,256))
np.expand_dims(resized, 0).shape

# plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = animal_model.predict(np.expand_dims(resized/255,0))
prediction
# Out:
# 1/1 [==============================] - 0s 82ms/step
# array([[0.1662917 , 0.04079366, 0.69590014, 0.00523077, 0.01112793,
#         0.00599439, 0.01019736, 0.02468122, 0.01663543, 0.02314748]],
#       dtype=float32)

# %%
# Category with highest probability
print(f'highest probability is for label {np.argmax(prediction, axis =1)}')
# Out:
# highest probability is for label [2]
